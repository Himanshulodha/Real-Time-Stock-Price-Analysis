# %% [markdown]
# # This Project is Real-Time Stock Price Analysis
#
# #### Description: The aim of this project is to develop a system that allows users to fetch, analyze, and visualize real-time stock price data. This project has several key objectives:
# #### 1.Fetch Real-Time Data
# #### 2.Analyze Data
# #### 3.Visualize Data
# #### 4.Interactive Application

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import streamlit as st
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot

# %%
def fetch_stock_data(ticker, period='1d', interval='1m'):
    stock = yf.Ticker(ticker)
    data = stock.history(period=period, interval=interval)
    return data

# Example usage
ticker = 'AAPL'
data = fetch_stock_data(ticker)
data.head()
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2024-07-29 09:30:00-04:00  216.679993  217.479996  216.679993  216.679993
# 2024-07-29 09:31:00-04:00  216.684601  216.889999  215.759995  216.119995
# 2024-07-29 09:32:00-04:00  216.115005  217.199997  215.929993  217.160004
# 2024-07-29 09:33:00-04:00  217.119995  217.589996  216.529999  216.736694
# 2024-07-29 09:34:00-04:00  216.735001  217.479996  216.600006  217.089996
#
#                             Volume  Dividends  Stock Splits
# Datetime
# 2024-07-29 09:30:00-04:00  1551381        0.0           0.0
# 2024-07-29 09:31:00-04:00   605123        0.0           0.0
# 2024-07-29 09:32:00-04:00   285186        0.0           0.0
# 2024-07-29 09:33:00-04:00   241540        0.0           0.0
# 2024-07-29 09:34:00-04:00   166513        0.0           0.0

# %%
def calculate_moving_average(data, window=5):
    data['MA'] = data['Close'].rolling(window=window).mean()
    return data

# Calculate moving average
data = calculate_moving_average(data)
data.tail()
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2024-07-29 12:57:00-04:00  218.710007  218.782501  218.699997  218.779999
# 2024-07-29 12:58:00-04:00  218.809998  218.880005  218.779999  218.809998
# 2024-07-29 12:59:00-04:00  218.800003  218.820007  218.721802  218.779999
# 2024-07-29 13:00:00-04:00  218.802505  218.860001  218.720001  218.809998
# 2024-07-29 13:01:00-04:00  218.809998  218.809998  218.809998  218.809998
#
#                            Volume  Dividends  Stock Splits          MA
# Datetime
# 2024-07-29 12:57:00-04:00   18792        0.0           0.0  218.774380
# 2024-07-29 12:58:00-04:00   36589        0.0           0.0  218.796381
# 2024-07-29 12:59:00-04:00   40291        0.0           0.0  218.785300
# 2024-07-29 13:00:00-04:00   28445        0.0           0.0  218.776999
# 2024-07-29 13:01:00-04:00       0        0.0           0.0  218.797998

# %%
def plot_stock_data(data, ticker):
    fig = go.Figure()
    # Plot closing price
    fig.add_trace(go.Scatter(
        x=data.index,
        y=data['Close'],
        mode='lines',
        name='Close Price'
    ))
    # Plot moving average
    fig.add_trace(go.Scatter(
        x=data.index,
        y=data['MA'],
        mode='lines',
        name='Moving Average'
    ))

    # Update layout
    fig.update_layout(
        title=f'{ticker} Stock Price',
        xaxis_title='Date',
        yaxis_title='Price',
        xaxis_rangeslider_visible=True
    )
    # Display the plot in Jupyter Notebook
    iplot(fig)

# %%
# Example usage
ticker = 'ACN'
data = fetch_stock_data(ticker)
data = calculate_moving_average(data)
plot_stock_data(data, ticker)
# Out:
# <div>                            <div id="b2155221-5637-49f0-b896-4c6a123a0cf4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b2155221-5637-49f0-b896-4c6a123a0cf4")) {                    Plotly.newPlot(                        "b2155221-5637-49f0-b896-4c6a123a0cf4",                        [{"mode":"lines","name":"Close Price","x":["2024-07-29T09:30:00-04:00","2024-07-29T09:31:00-04:00","2024-07-29T09:32:00-04:00","2024-07-29T09:33:00-04:00","2024-07-29T09:34:00-04:00","2024-07-29T09:35:00-04:00","2024-07-29T09:36:00-04:00","2024-07-29T09:37:00-04:00","2024-07-29T09:38:00-04:00","2024-07-29T09:39:00-04:00","2024-07-29T09:40:00-04:00","2024-07-29T09:41:00-04:00","2024-07-29T09:42:00-04:00","2024-07-29T09:43:00-04:00","2024-07-29T09:44:00-04:00","2024-07-29T09:45:00-04:00","2024-07-29T09:46:00-04:00","2024-07-29T09:47:00-04:00","2024-07-29T09:48: